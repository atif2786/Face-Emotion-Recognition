# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 6204 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "train", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 6204 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="model_weights.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_10552/564963302.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 24.8264 - accuracy: 0.1906
# Epoch 00001: val_accuracy improved from -inf to 0.30078, saving model to model_weights.h5
# 10/10 [==============================] - 46s 4s/step - loss: 24.8264 - accuracy: 0.1906 - val_loss: 16.9882 - val_accuracy: 0.3008
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 15.2541 - accuracy: 0.2531
# Epoch 00002: val_accuracy improved from 0.30078 to 0.34766, saving model to model_weights.h5
# 10/10 [==============================] - 43s 4s/step - loss: 15.2541 - accuracy: 0.2531 - val_loss: 11.9021 - val_accuracy: 0.3477
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 9.2977 - accuracy: 0.3594
# Epoch 00003: val_accuracy improved from 0.34766 to 0.41016, saving model to model_weights.h5
# 10/10 [==============================] - 39s 4s/step - loss: 9.2977 - accuracy: 0.3594 - val_loss: 5.6771 - val_accuracy: 0.4102
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 6.6059 - accuracy: 0.3812
# Epoch 00004: val_accuracy did not improve from 0.41016
# 10/10 [==============================] - 40s 4s/step - loss: 6.6059 - accuracy: 0.3812 - val_loss: 6.1537 - val_accuracy: 0.3867
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 6.4868 - accuracy: 0.3688
# Epoch 00005: val_accuracy did not improve from 0.41016
# 10/10 [==============================] - 43s 4s/step - loss: 6.4868 - accuracy: 0.3688 - val_loss: 5.4676 - val_accuracy: 0.3711
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 5.0475 - accuracy: 0.4563
# Epoch 00006: val_accuracy improved from 0.41016 to 0.41797, saving model to model_weights.h5
# 10/10 [==============================] - 37s 4s/step - loss: 5.0475 - accuracy: 0.4563 - val_loss: 4.3787 - val_accuracy: 0.4180
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 5.1730 - accuracy: 0.3875
# Epoch 00007: val_accuracy improved from 0.41797 to 0.45703, saving model to model_weights.h5
# 10/10 [==============================] - 38s 4s/step - loss: 5.1730 - accuracy: 0.3875 - val_loss: 5.2257 - val_accuracy: 0.4570
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 4.4164 - accuracy: 0.4625
# Epoch 00008: val_accuracy improved from 0.45703 to 0.47266, saving model to model_weights.h5
# 10/10 [==============================] - 40s 4s/step - loss: 4.4164 - accuracy: 0.4625 - val_loss: 3.5836 - val_accuracy: 0.4727
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 5.6862 - accuracy: 0.3812
# Epoch 00009: val_accuracy did not improve from 0.47266
# 10/10 [==============================] - 41s 4s/step - loss: 5.6862 - accuracy: 0.3812 - val_loss: 5.0469 - val_accuracy: 0.3984
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 4.7103 - accuracy: 0.4156
# Epoch 00010: val_accuracy improved from 0.47266 to 0.53906, saving model to model_weights.h5
# 10/10 [==============================] - 43s 4s/step - loss: 4.7103 - accuracy: 0.4156 - val_loss: 3.9349 - val_accuracy: 0.5391
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 4.2439 - accuracy: 0.4875
# Epoch 00011: val_accuracy improved from 0.53906 to 0.55859, saving model to model_weights.h5
# 10/10 [==============================] - 49s 5s/step - loss: 4.2439 - accuracy: 0.4875 - val_loss: 4.6335 - val_accuracy: 0.5586
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 4.2637 - accuracy: 0.4938
# Epoch 00012: val_accuracy did not improve from 0.55859
# 10/10 [==============================] - 40s 4s/step - loss: 4.2637 - accuracy: 0.4938 - val_loss: 4.8223 - val_accuracy: 0.4453
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 4.7687 - accuracy: 0.4563
# Epoch 00013: val_accuracy did not improve from 0.55859
# 10/10 [==============================] - 45s 5s/step - loss: 4.7687 - accuracy: 0.4563 - val_loss: 3.8812 - val_accuracy: 0.4531
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 5.2748 - accuracy: 0.4313
# Epoch 00014: val_accuracy did not improve from 0.55859
# 10/10 [==============================] - 42s 4s/step - loss: 5.2748 - accuracy: 0.4313 - val_loss: 3.8038 - val_accuracy: 0.4844
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 4.4247 - accuracy: 0.4563
# Epoch 00015: val_accuracy did not improve from 0.55859
# 10/10 [==============================] - 43s 4s/step - loss: 4.4247 - accuracy: 0.4563 - val_loss: 4.9813 - val_accuracy: 0.4805
# Epoch 16/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7268 - accuracy: 0.4500
# Epoch 00016: val_accuracy did not improve from 0.55859
# 10/10 [==============================] - 38s 4s/step - loss: 5.7268 - accuracy: 0.4500 - val_loss: 5.4386 - val_accuracy: 0.5195
# Epoch 00016: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("model_weights.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "images\surprise.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
#  the image is of Surprise
